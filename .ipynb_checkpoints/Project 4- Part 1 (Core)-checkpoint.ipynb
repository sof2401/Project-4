# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline

# Models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from sklearn import set_config
set_config(transform_output= 'pandas')

# %%
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
def classification_metrics(y_true, y_pred, label="",
                           output_dict=False, figsize=(8,4),
                           normalize='true', cmap='Blues',
                           colorbar=False):
  # Get the classification report
  report = classification_report(y_true, y_pred)
  ## Print header and report
  header = "-"*70
  print(header, f" Classification Metrics: {label}", header, sep='\n')
  print(report)
  ## CONFUSION MATRICES SUBPLOTS
  fig, axes = plt.subplots(ncols=2, figsize=figsize)
  # create a confusion matrix  of raw counts
  ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=None, cmap='gist_gray', colorbar=colorbar,
                ax = axes[0],);
  axes[0].set_title("Raw Counts")
  # create a confusion matrix with the test data
  ConfusionMatrixDisplay.from_predictions(y_true, y_pred,
                normalize=normalize, cmap=cmap, colorbar=colorbar,
                ax = axes[1]);
  axes[1].set_title("Normalized Confusion Matrix")
  # Adjust layout and show figure
  fig.tight_layout()
  plt.show()
  # Return dictionary of classification_report
  if output_dict==True:
    report_dict = classification_report(y_true, y_pred, output_dict=True)
    return report_dict
    
    
    
def evaluate_classification(model, X_train, y_train, X_test, y_test,
                         figsize=(6,4), normalize='true', output_dict = False,
                            cmap_train='Blues', cmap_test="Reds",colorbar=False):
  # Get predictions for training data
  y_train_pred = model.predict(X_train)
  # Call the helper function to obtain regression metrics for training data
  results_train = classification_metrics(y_train, y_train_pred, #verbose = verbose,
                                     output_dict=True, figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_train,
                                     label='Training Data')
  print()
  # Get predictions for test data
  y_test_pred = model.predict(X_test)
  # Call the helper function to obtain regression metrics for test data
  results_test = classification_metrics(y_test, y_test_pred, #verbose = verbose,
                                  output_dict=True,figsize=figsize,
                                         colorbar=colorbar, cmap=cmap_test,
                                    label='Test Data' )
  if output_dict == True:
    # Store results in a dataframe if ouput_frame is True
    results_dict = {'train':results_train,
                    'test': results_test}
    return results_dict

# %%
df= pd.read_csv('Data/cirrhosis.csv')
df.head()
# Out:
#    ID  N_Days Status             Drug    Age Sex Ascites Hepatomegaly Spiders  \
# 0   1     400      D  D-penicillamine  21464   F       Y            Y       Y
# 1   2    4500      C  D-penicillamine  20617   F       N            Y       Y
# 2   3    1012      D  D-penicillamine  25594   M       N            N       N
# 3   4    1925      D  D-penicillamine  19994   F       N            Y       Y
# 4   5    1504     CL          Placebo  13918   F       N            Y       Y
#
#   Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4     N        3.4        279.0     3.53   143.0     671.0  113.15
#
#    Tryglicerides  Platelets  Prothrombin  Stage
# 0          172.0      190.0         12.2    4.0
# 1           88.0      221.0         10.6    3.0
# 2           55.0      151.0         12.0    4.0
# 3           92.0      183.0         10.3    4.0
# 4           72.0      136.0         10.9    3.0

# %%
df.isna().sum()
# Out:
# ID                 0
# N_Days             0
# Status             0
# Drug             106
# Age                0
# Sex                0
# Ascites          106
# Hepatomegaly     106
# Spiders          106
# Edema              0
# Bilirubin          0
# Cholesterol      134
# Albumin            0
# Copper           108
# Alk_Phos         106
# SGOT             106
# Tryglicerides    136
# Platelets         11
# Prothrombin        2
# Stage              6
# dtype: int64

# %%
df= df.dropna()
df.isna().sum()
# Out:
# ID               0
# N_Days           0
# Status           0
# Drug             0
# Age              0
# Sex              0
# Ascites          0
# Hepatomegaly     0
# Spiders          0
# Edema            0
# Bilirubin        0
# Cholesterol      0
# Albumin          0
# Copper           0
# Alk_Phos         0
# SGOT             0
# Tryglicerides    0
# Platelets        0
# Prothrombin      0
# Stage            0
# dtype: int64

# %%
df['Age']= df['Age']/365
df
# Out:
#       ID  N_Days Status             Drug        Age Sex Ascites Hepatomegaly  \
# 0      1     400      D  D-penicillamine  58.805479   F       Y            Y
# 1      2    4500      C  D-penicillamine  56.484932   F       N            Y
# 2      3    1012      D  D-penicillamine  70.120548   M       N            N
# 3      4    1925      D  D-penicillamine  54.778082   F       N            Y
# 4      5    1504     CL          Placebo  38.131507   F       N            Y
# ..   ...     ...    ...              ...        ...  ..     ...          ...
# 307  308    1153      C  D-penicillamine  61.224658   F       N            Y
# 308  309     994      C          Placebo  58.339726   F       N            N
# 309  310     939      C  D-penicillamine  62.375342   F       N            N
# 310  311     839      C  D-penicillamine  38.024658   F       N            N
# 311  312     788      C          Placebo  33.175342   F       N            N
#
#     Spiders Edema  Bilirubin  Cholesterol  Albumin  Copper  Alk_Phos    SGOT  \
# 0         Y     Y       14.5        261.0     2.60   156.0    1718.0  137.95
# 1         Y     N        1.1        302.0     4.14    54.0    7394.8  113.52
# 2         N     S        1.4        176.0     3.48   210.0     516.0   96.10
# 3         Y     S        1.8        244.0     2.54    64.0    6121.8   60.63
# 4         Y     N        3.4        279.0     3.53   143.0     671.0  113.15
# ..      ...   ...        ...          ...      ...     ...       ...     ...
# 307       N     N        0.4        246.0     3.58    24.0     797.0   91.00
# 308       N     N        0.4        260.0     2.75    41.0    1166.0   70.00
# 309       N     N        1.7        434.0     3.35    39.0    1713.0  171.00
# 310       N     N        2.0        247.0     3.16    69.0    1050.0  117.00
# 311       Y     N        6.4        576.0     3.79   186.0    2115.0  136.00
#
#      Tryglicerides  Platelets  Prothrombin  Stage
# 0            172.0      190.0         12.2    4.0
# 1             88.0      221.0         10.6    3.0
# 2             55.0      151.0         12.0    4.0
# 3             92.0      183.0         10.3    4.0
# 4             72.0      136.0         10.9    3.0
# ..             ...        ...          ...    ...
# 307          113.0      288.0         10.4    2.0
# 308           82.0      231.0         10.8    2.0
# 309          100.0      234.0         10.2    2.0
# 310           88.0      335.0         10.5    2.0
# 311          149.0      200.0         10.8    2.0
#
# [276 rows x 20 columns]

# %%
corr= df.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr,cmap='coolwarm');
# Out:
# /var/folders/fc/lxtc0_tj33b65krh167ynf300000gn/T/ipykernel_38561/2006108646.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= df.corr()

# %%
# PREPROCESSING

target= 'Drug'

drop_cols= ['ID']

X = df.drop(columns=[target] + drop_cols)
y= df[target]

X_train,X_test,y_train,y_test = train_test_split(X,y, random_state=42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

num_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
cat_cols = X_train.select_dtypes(include=['object']).columns

preprocessor = ColumnTransformer(transformers=[
        ('num', StandardScaler(), num_cols), 
        ('cat', OneHotEncoder(sparse_output= False), cat_cols)], verbose_feature_names_out= False)

preprocessor.fit(X_train)

X_train_preprocessed = preprocessor.transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)

# %%
rf_df = RandomForestClassifier(random_state=42)

rf_df.fit(X_train_preprocessed, y_train)

evaluate_classification(rf_df, X_train_preprocessed, y_train, X_test_preprocessed, y_test)
# Out:
# ----------------------------------------------------------------------
#  Classification Metrics: Training Data
# ----------------------------------------------------------------------
#                  precision    recall  f1-score   support
#
# D-penicillamine       1.00      1.00      1.00        98
#         Placebo       1.00      1.00      1.00       109
#
#        accuracy                           1.00       207
#       macro avg       1.00      1.00      1.00       207
#    weighted avg       1.00      1.00      1.00       207
# ----------------------------------------------------------------------
#  Classification Metrics: Test Data
# ----------------------------------------------------------------------
#                  precision    recall  f1-score   support
#
# D-penicillamine       0.59      0.53      0.56        38
#         Placebo       0.49      0.55      0.52        31
#
#        accuracy                           0.54        69
#       macro avg       0.54      0.54      0.54        69
#    weighted avg       0.54      0.54      0.54        69

# %%
from sklearn.inspection import permutation_importance

# Permutation importance takes a fit model and the test data.
r = permutation_importance(rf_df, X_test_preprocessed, y_test,n_repeats =10, random_state = 42)
r.keys()
# Out:
# dict_keys(['importances_mean', 'importances_std', 'importances'])

# %%
## can make the mean importances into a series
permutation_importances = pd.Series(r['importances_mean'],index=rf_df.feature_names_in_,
                           name = 'permutation importance')
permutation_importances = permutation_importances.sort_values(ascending=False)
permutation_importances
# Out:
# Age               0.098551
# Bilirubin         0.082609
# Prothrombin       0.075362
# Copper            0.073913
# Cholesterol       0.049275
# N_Days            0.040580
# Alk_Phos          0.040580
# Platelets         0.039130
# Hepatomegaly_N    0.037681
# Tryglicerides     0.034783
# Albumin           0.031884
# Edema_N           0.021739
# Status_C          0.021739
# Ascites_N         0.018841
# Status_D          0.018841
# Sex_F             0.017391
# Ascites_Y         0.014493
# SGOT              0.014493
# Hepatomegaly_Y    0.005797
# Sex_M             0.002899
# Spiders_Y         0.001449
# Edema_Y           0.001449
# Status_CL         0.000000
# Spiders_N        -0.004348
# Stage            -0.010145
# Edema_S          -0.011594
# Name: permutation importance, dtype: float64

# %%
# EXPLANATORY VISUALIZATIONS

# %%
# Feature 1 Viz
plt.figure(figsize=(12, 6))

sns.scatterplot(x=df['Age'], y=df['Drug'], hue=df['Drug'])
plt.xlabel(feature1)
plt.ylabel('Drug')
plt.title(f'Scatter Plot of {feature1} vs. Target')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs. Target')

# %% [markdown]
# With this scatterplot we can see the range of different people's ages that took either the D- penicillamine vs the placebo.

# %%
# Feature 2 Viz
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 2)
sns.scatterplot(y=df['Bilirubin'], x=df['Drug'], hue=df['Bilirubin'])
plt.xlabel(feature2)
plt.ylabel('Level of Bilirubin')
plt.title(f'Scatter Plot of {feature2} vs. Target')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Bilirubin vs. Target')

# %% [markdown]
# With this scatterplot we can visualize the differnt levels of Bilirubin of the patients that took the D- penicillamine vs the Placebo.
